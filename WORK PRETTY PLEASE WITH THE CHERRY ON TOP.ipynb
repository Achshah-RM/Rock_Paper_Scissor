# %%
from tkinter import *
from tkinter import ttk
import random
from PIL import ImageTk, Image
import tkinter

# %%
rock = 1
paper = 2
scissor = 3

# %%
com = random.randint(1,3)

# %%
def calculate(*args): 
    if com == 1:

        img = Image.open("paper.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img3 = ImageTk.PhotoImage(resize_image3)

        tkinter.Label(mainframe, image = img).grid(column = 1, row = 7, sticky = W)
        tkinter.Label(mainframe, image = img3).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 2, row = 7, sticky = N)
        ttk.Label(mainframe, text = "Victory!", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()
    elif com ==2:

        img = Image.open("paper.jpeg")
        img2 = Image.open("scissor.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image2 = img2.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img2 = ImageTk.PhotoImage(resize_image2)
        img3 = ImageTk.PhotoImage(resize_image3)

        label = tkinter.Label(mainframe, image = img).grid(column = 1, row = 7, sticky = W)
        label = tkinter.Label(mainframe, image = img).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 2, row = 7, sticky = N)
        ttk.Label(mainframe, text = "Draw", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()
        
    else:

        img = Image.open("paper.jpeg")
        img2 = Image.open("scissor.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image2 = img2.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img2 = ImageTk.PhotoImage(resize_image2)
        img3 = ImageTk.PhotoImage(resize_image3)

        label = tkinter.Label(mainframe, image = img).grid(column = 1, row = 7, sticky = W)
        label = tkinter.Label(mainframe, image = img2).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 2, row = 7, sticky = N)
        ttk.Label(mainframe, text = "LOST", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()

# %%
def calculate1():
    if com ==1:

        img = Image.open("paper.jpeg")
        img2 = Image.open("scissor.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image2 = img2.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img2 = ImageTk.PhotoImage(resize_image2)
        img3 = ImageTk.PhotoImage(resize_image3)

        label = tkinter.Label(mainframe, image = img3).grid(column = 1, row = 7, sticky = W)
        label = tkinter.Label(mainframe, image = img3).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 2, row = 7, sticky = N)
        ttk.Label(mainframe, text = "Draw", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()
        
    elif com ==2:

        img = Image.open("paper.jpeg")
        img2 = Image.open("scissor.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image2 = img2.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img2 = ImageTk.PhotoImage(resize_image2)
        img3 = ImageTk.PhotoImage(resize_image3)

        label = tkinter.Label(mainframe, image = img3).grid(column = 1, row = 7, sticky = W)
        label = tkinter.Label(mainframe, image = img).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 2, row = 7, sticky = N)
        ttk.Label(mainframe, text = "LOST", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()
        
    else:

        img = Image.open("paper.jpeg")
        img2 = Image.open("scissor.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image2 = img2.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img2 = ImageTk.PhotoImage(resize_image2)
        img3 = ImageTk.PhotoImage(resize_image3)

        label = tkinter.Label(mainframe, image = img3).grid(column = 1, row = 7, sticky = W)
        label = tkinter.Label(mainframe, image = img2).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 2, row = 7, sticky = N)
        ttk.Label(mainframe, text = "Victory!", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()

# %%
def calculate2():
    if com ==1:

        img = Image.open("paper.jpeg")
        img2 = Image.open("scissor.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image2 = img2.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img2 = ImageTk.PhotoImage(resize_image2)
        img3 = ImageTk.PhotoImage(resize_image3)

        label = tkinter.Label(mainframe, image = img2).grid(column = 1, row = 7, sticky = W)
        label = tkinter.Label(mainframe, image = img3).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 3, row = 7, sticky = N)
        ttk.Label(mainframe, text = "LOST", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()
        
    elif com ==2:

        img = Image.open("paper.jpeg")
        img2 = Image.open("scissor.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image2 = img2.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img2 = ImageTk.PhotoImage(resize_image2)
        img3 = ImageTk.PhotoImage(resize_image3)

        label = tkinter.Label(mainframe, image = img2).grid(column = 1, row = 7, sticky = W)
        label = tkinter.Label(mainframe, image = img).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 2, row = 7, sticky = N)
        ttk.Label(mainframe, text = "Victory!", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()
        
    else:
        
        img = Image.open("paper.jpeg")
        img2 = Image.open("scissor.jpeg")
        img3 = Image.open("roc.jpg")
        resize_image = img.resize((200, 200))
        resize_image2 = img2.resize((200, 200))
        resize_image3 = img3.resize((200, 200))

        img = ImageTk.PhotoImage(resize_image)
        img2 = ImageTk.PhotoImage(resize_image2)
        img3 = ImageTk.PhotoImage(resize_image3)

        label = tkinter.Label(mainframe, image = img2).grid(column = 1, row = 7, sticky = W)
        label = tkinter.Label(mainframe, image = img2).grid(column = 3, row = 7, sticky = E)
        ttk.Label(mainframe, text = "VS", font = ("Chalkduster", 150)).grid(column = 2, row = 7, sticky = N)
        ttk.Label(mainframe, text = "Draw", 
                  font = ("American Typewriter", 100)).grid(column = 2, row = 9, sticky = N)
        root.mainloop()

# %%
def play():
    
    ttk.Button(mainframe, text = "Paper", command = calculate). grid(column = 1, row = 5,sticky = E)
    ttk.Button(mainframe, text = "Rock", command = calculate1). grid(column = 2, row = 5,sticky = N)
    ttk.Button(mainframe, text = "Scissor",command = calculate2). grid(column = 3, row = 5,sticky = W)

    ttk.Label(mainframe, text = "Choose Your fighter", font = ("Arial", 50)).grid(column = 2, row = 3, sticky = N)
    root.mainloop()

# %%
root = Tk() 
root.title("Rock Paper Scissor")
mainframe = ttk.Frame(root, padding = " 100 100 500 500 ") 
mainframe.grid(column = 0, row = 0, sticky = (N, W, E, S)) 
mainframe.columnconfigure(0, weight=1) 
mainframe.rowconfigure(0, weight=1)

ttk.Button(mainframe, text = "PLAY", command = play). grid(column = 2, row = 2,sticky = N)
ttk.Label(mainframe, text = "Do you want to play this game?!?", font = ("Arial", 50)).grid(column = 2, row = 1, sticky = N)
root.mainloop()
